# %% [markdown]
# # Images as Grids of Pixels

# %% [markdown]
# ### Import resources

# %%
import numpy as np
import matplotlib.image as mpimg  # for reading in images

import matplotlib.pyplot as plt
import cv2  # computer vision library

# %matplotlib inline

# %% [markdown]
# ### Read in and display the image

# %%
# Read in the image
image = mpimg.imread('images/benz.jpg')

# Print out the image dimensions
print('Image dimensions:', image.shape)

# Change from color to grayscale
gray_image = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)

plt.imshow(image, cmap='gray')
# Out:
# Image dimensions: (480, 640, 3)

# %%
# Print specific grayscale pixel values
# What is the pixel value at x = 400 and y = 300 (on the body of the car)?

x = 400
y = 300

print(gray_image[y,x])
# Out:
# 1

# %%
# Two library behaving differently
im1 = cv2.imread('images/red.jpeg')
im2 = mpimg.imread('images/red.jpeg')
print('Image dimensions:', im1.shape)
print('Image dimensions:', im2.shape)
print(im1[120,120])
print(im2[120,120])
# Out:
# Image dimensions: (225, 225, 3)
# Image dimensions: (225, 225, 3)
# [  1   4 196]
# [196   4   1]

# %%
#Find the maximum and minimum grayscale values in this image

max_val = np.amax(gray_image)
min_val = np.amin(gray_image)

print('Max: ', max_val)
print('Min: ', min_val)

# %%
# Create a 5x5 image using just grayscale, numerical values
tiny_image = np.array([[0, 20, 30, 150, 120],
                      [200, 200, 250, 70, 3],
                      [50, 180, 85, 40, 90],
                      [240, 100, 50, 255, 10],
                      [30, 0, 75, 190, 220]])

# To show the pixel grid, use matshow
plt.matshow(tiny_image, cmap='gray')

## TODO: See if you can draw a tiny smiley face or something else!
